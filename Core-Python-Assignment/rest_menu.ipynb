# %%
class Menu:
    def __init__(self,menu):
        self.menu=menu
    def add_items(self,item):
        self.menu.append(item)
        return f"updated menu:{self.menu}"
    def remove_items(self,item):
        if item not in self.menu:
            return "item not available"
        self.menu.remove(item)
        return f"updated menu:{self.menu}"
    def available(self,item):
        if item in self.menu:
            return f"{item} is available"
        else:
            return "Not available"
ob=Menu(["Pizza", "Burger", "Pasta", "Salad"])
print(ob.add_items("Tacos"))
print(ob.remove_items("Salad"))
print(ob.remove_items("paneer"))
print(ob.available("Burger"))
# Out:
# updated menu:['Pizza', 'Burger', 'Pasta', 'Salad', 'Tacos']
# updated menu:['Pizza', 'Burger', 'Pasta', 'Tacos']
# item not available
# Burger is available
