# %% [markdown]
# Descriptive statistics
# handle missing values
# if error (?)-handle them
# check distribution for both numerical&categorical
# correlation matrix heatmap draw insights
# if you hypothesis testing
# encoding(one hot or label)
# scaling standard normalization
# split data,train linearReg,polynomialReg,lasso-ridge,best alpha for lasso ridge,r2score mse mae rmse

# %%
import pandas as pd
